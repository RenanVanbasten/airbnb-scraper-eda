# %%
import pandas as pd

df = pd.read_csv('../data/airbnb_listings.csv')
df
# Out:
#                            titulo  \
# 0   Apartamento em Rio de Janeiro
# 1              Loft em Copacabana
# 2       Apartamento em Copacabana
# 3   Apartamento em Rio de Janeiro
# 4       Apartamento em Copacabana
# 5   Apartamento em Rio de Janeiro
# 6   Apartamento em Rio de Janeiro
# 7   Apartamento em Rio de Janeiro
# 8   Apartamento em Rio de Janeiro
# 9   Apartamento em Rio de Janeiro
# 10  Apartamento em Rio de Janeiro
# 11  Apartamento em Rio de Janeiro
# 12  Apartamento em Rio de Janeiro
# 13  Apartamento em Rio de Janeiro
# 14      Apartamento em Copacabana
# 15      Apartamento em Copacabana
# 16  Apartamento em Rio de Janeiro
# 17         Loft em Rio de Janeiro
#
#                                             descricao            avaliacao  \
# 0                         Praia e cidade com conforto   4,83 48 avaliações
# 1                             Moderno Loft Copacabana  4,98 235 avaliações
# 2                           Apartamento em Copacabana  4,87 180 avaliações
# ...
